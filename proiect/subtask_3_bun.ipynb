# %%
import json, os, torch
import numpy as np
from collections import Counter
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
from torch.utils.data import Dataset, DataLoader
from torch.optim import AdamW
import torch.nn as nn
from transformers import (
    BertTokenizer,
    BertForSequenceClassification,
    get_linear_schedule_with_warmup
)
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Build category lists
# Enumerate every entity#attribute combination for restaurant, laptop, hotel, and OUT_OF_SCOPE domains, then prepare the bidirectional label maps `category2id` and `id2category` used by the classifier.

# %%
def build_category_list():
    # Restaurant
    restaurant_entities = [
        "RESTAURANT", "FOOD", "DRINKS", "AMBIENCE", "SERVICE", "LOCATION"
    ]
    restaurant_attrs = [
        "GENERAL", "PRICES", "QUALITY", "STYLE_OPTIONS", "MISCELLANEOUS"
    ]

    # Laptop
    laptop_entities = [
        "LAPTOP", "DISPLAY", "KEYBOARD", "MOUSE", "MOTHERBOARD", "CPU",
        "FANS_COOLING", "PORTS", "MEMORY", "POWER_SUPPLY", "OPTICAL_DRIVES",
        "BATTERY", "GRAPHICS", "HARD_DISK", "MULTIMEDIA_DEVICES", "HARDWARE",
        "SOFTWARE", "OS", "WARRANTY", "SHIPPING", "SUPPORT", "COMPANY"
    ]
    laptop_attrs = [
        "GENERAL", "PRICE", "QUALITY", "DESIGN_FEATURES",
        "OPERATION_PERFORMANCE", "USABILITY", "PORTABILITY",
        "CONNECTIVITY", "MISCELLANEOUS"
    ]

    # Hotel
    hotel_entities = [
        "HOTEL", "ROOMS", "FACILITIES", "ROOM_AMENITIES",
        "SERVICE", "LOCATION", "FOOD_DRINKS"
    ]
    hotel_attrs = [
        "GENERAL", "PRICE", "COMFORT", "CLEANLINESS",
        "QUALITY", "DESIGN_FEATURES",
        "STYLE_OPTIONS", "MISCELLANEOUS"
    ]

    # OUT_OF_SCOPE
    out_of_scope_entities = ["OUT_OF_SCOPE"]
    out_of_scope_attrs = [
        "GENERAL",
        "OPERATION_PERFORMANCE",
        "DESIGN_FEATURES",
        "USABILITY"
    ]

    categories = []

    # Restaurant
    for e in restaurant_entities:
        for a in restaurant_attrs:
            categories.append(f"{e}#{a}")

    # Laptop
    for e in laptop_entities:
        for a in laptop_attrs:
            categories.append(f"{e}#{a}")

    # Hotel
    for e in hotel_entities:
        for a in hotel_attrs:
            categories.append(f"{e}#{a}")

    # OUT_OF_SCOPE
    for e in out_of_scope_entities:
        for a in out_of_scope_attrs:
            categories.append(f"{e}#{a}")

    return categories


# Label mappings
ALL_CATEGORIES = build_category_list()
category2id = {cat: i for i, cat in enumerate(ALL_CATEGORIES)}
id2category = {i: cat for cat, i in category2id.items()}

NUM_LABELS = len(ALL_CATEGORIES)

# %% [markdown]
# ## Input text helper
# Concatenate the raw sentence with its aspect, opinion, and VA scores into a single prompt string expected by BERT.

# %%
def build_input(text, aspect, opinion, va):
    return (
        f"Text: {text} "
        f"Aspect: {aspect}. "
        f"Opinion: {opinion}. "
        f"VA: {va}"
    )

# %% [markdown]
# ## PyTorch dataset for classification
# Read the JSONL file, expand each quadruplet into a (text, label) pair, and tokenize with truncation/padding to fixed length for BERT inputs.

# %%
# DATASET PyTorch

class CategoryDataset(Dataset):
    def __init__(self, path, tokenizer, category2id, max_len=128):
        self.samples = []
        self.tokenizer = tokenizer
        self.max_len = max_len

        with open(path, encoding="utf-8") as f:
            for line in f:
                data = json.loads(line)
                text = data["Text"]

                for t in data["Quadruplet"]:
                    input_text = build_input(
                        text,
                        t["Aspect"],
                        t["Opinion"],
                        t["VA"]
                    )

                    label = category2id[t["Category"]]

                    self.samples.append((input_text, label))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        text, label = self.samples[idx]

        enc = self.tokenizer(
            text,
            truncation=True,
            padding="max_length",
            max_length=self.max_len,
            return_tensors="pt"
        )

        return {
            "input_ids": enc["input_ids"].squeeze(0),
            "attention_mask": enc["attention_mask"].squeeze(0),
            "labels": torch.tensor(label, dtype=torch.long)
        }

# %% [markdown]
# ## Class weights helper
# Compute inverse-frequency weights for cross-entropy to mitigate class imbalance.

# %%
def compute_class_weights(samples, num_labels):
    counts = Counter(label for _, label in samples)
    max_count = max(counts.values()) if counts else 1
    weights = [max_count / counts.get(i, 1) for i in range(num_labels)]
    return torch.tensor(weights, dtype=torch.float)

# %% [markdown]
# ## Data splitting utility
# Split the loaded samples into training and validation sets based on a specified ratio.

# %%
def split_data_from_file(file_path, train_ratio=0.8, random_state=42):
    samples = []
    labels = []

    with open(file_path, encoding="utf-8") as f:
        for line in f:
            data = json.loads(line)
            text = data["Text"]

            for t in data["Quadruplet"]:
                input_text = build_input(
                    text,
                    t["Aspect"],
                    t["Opinion"],
                    t["VA"]
                )
                label = category2id[t["Category"]]
                samples.append((input_text, label))
                labels.append(label)

    try:
        train_samples, val_samples, _, _ = train_test_split(
            samples,
            labels,
            train_size=train_ratio,
            random_state=random_state,
            shuffle=True,
            stratify=labels
        )
        print("Using stratified split to preserve class balance")
    except ValueError as e:
        print(f"Stratification failed (some classes have too few samples), using regular split")
        train_samples, val_samples = train_test_split(
            samples,
            train_size=train_ratio,
            random_state=random_state,
            shuffle=True
        )

    return train_samples, val_samples


class CategoryDatasetFromSamples(Dataset):
    """
    Dataset that takes pre-loaded samples instead of reading from file.
    """
    def __init__(self, samples, tokenizer, max_len=128):
        self.samples = samples
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        text, label = self.samples[idx]

        enc = self.tokenizer(
            text,
            truncation=True,
            padding="max_length",
            max_length=self.max_len,
            return_tensors="pt"
        )

        return {
            "input_ids": enc["input_ids"].squeeze(0),
            "attention_mask": enc["attention_mask"].squeeze(0),
            "labels": torch.tensor(label, dtype=torch.long)
        }

# %% [markdown]
# ## Initialize BERT model
# Load `bert-base-uncased` for sequence classification and set the output dimension to match the number of category labels.

# %%
def build_model(num_labels):
    return BertForSequenceClassification.from_pretrained(
        "bert-base-uncased",
        num_labels=num_labels
    )

# %% [markdown]
# ## Training loop and early stopping
# Runs multiple epochs over the DataLoader and tracks loss + macro-F1.
# - Per batch: (1) zero gradients, (2) forward pass with labels to get loss/logits, (3) backprop, (4) optimizer step, (5) accumulate loss and predictions.
# - Per epoch: compute average loss, accuracy, and macro-F1 on all seen batches and log them.
# - Early stopping: monitor macro-F1; if it fails to improve by at least `min_delta` over the best score for `patience` consecutive epochs, halt training to avoid overfitting and wasted compute.
# - Returns: the best macro-F1 achieved before stopping.

# %%
def train_model(
    model,
    train_loader,
    val_loader,
    optimizer,
    scheduler,
    criterion,
    device,
    epochs=10,
    patience=3,
    min_delta=1e-4
):
    best_val_f1 = 0.0
    best_state = None
    epochs_no_improve = 0

    for epoch in range(epochs):
        model.train()

        total_loss = 0.0
        all_preds = []
        all_labels = []

        for batch in train_loader:
            optimizer.zero_grad()

            input_ids = batch["input_ids"].to(device)
            attention_mask = batch["attention_mask"].to(device)
            labels = batch["labels"].to(device)

            outputs = model(
                input_ids=input_ids,
                attention_mask=attention_mask
            )

            logits = outputs.logits
            loss = criterion(logits, labels)

            loss.backward()
            optimizer.step()
            scheduler.step()

            total_loss += loss.item()

            preds = torch.argmax(logits, dim=1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

        avg_loss = total_loss / len(train_loader)
        train_acc = accuracy_score(all_labels, all_preds)
        train_macro_f1 = f1_score(all_labels, all_preds, average="macro")

        # VALIDATION 
        model.eval()
        val_loss = 0.0
        val_preds = []
        val_labels = []

        with torch.no_grad():
            for batch in val_loader:
                input_ids = batch["input_ids"].to(device)
                attention_mask = batch["attention_mask"].to(device)
                labels = batch["labels"].to(device)

                outputs = model(
                    input_ids=input_ids,
                    attention_mask=attention_mask
                )

                logits = outputs.logits
                loss = criterion(logits, labels)

                val_loss += loss.item()

                preds = torch.argmax(logits, dim=1)
                val_preds.extend(preds.cpu().numpy())
                val_labels.extend(labels.cpu().numpy())

        val_avg_loss = val_loss / len(val_loader)
        val_acc = accuracy_score(val_labels, val_preds)
        val_macro_f1 = f1_score(val_labels, val_preds, average="macro")

        print(
            f"[Epoch {epoch+1}] "
            f"Train Loss: {avg_loss:.4f} | Train Acc: {train_acc:.4f} | Train Macro-F1: {train_macro_f1:.4f} "
            f"|| Val Loss: {val_avg_loss:.4f} | Val Acc: {val_acc:.4f} | Val Macro-F1: {val_macro_f1:.4f}"
        )

        # EARLY STOPPING ON VAL F1 
        if val_macro_f1 > best_val_f1 + min_delta:
            best_val_f1 = val_macro_f1
            best_state = {k: v.clone().detach().cpu() for k, v in model.state_dict().items()}
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
            print(f"  - No validation improvement for {epochs_no_improve}/{patience} epochs")

        if epochs_no_improve >= patience:
            print(
                f"  - Early stopping at epoch {epoch+1}. "
                f"Best Val Macro-F1: {best_val_f1:.4f}"
            )
            break

    if best_state is not None:
        model.load_state_dict(best_state)

    return best_val_f1

# %% [markdown]
# ## Prediction helper
# Builds the combined input string for a single example, tokenizes it, performs a forward pass on the model, and returns the category with the highest logit (argmax).

# %%
def predict_category(model, tokenizer, device, text, aspect, opinion, va):
    model.eval()

    input_text = build_input(text, aspect, opinion, va)

    enc = tokenizer(
        input_text,
        return_tensors="pt",
        truncation=True,
        padding=True
    )

    enc = {k: v.to(device) for k, v in enc.items()}

    with torch.no_grad():
        logits = model(**enc).logits

    pred_id = torch.argmax(logits, dim=1).item()
    return id2category[pred_id]

# %% [markdown]
# ## Evaluate on validation samples
# Evaluate the model on a pre-split set of validation samples (not from file).

# %%
def evaluate_on_samples(model, tokenizer, val_samples, device, batch_size=8):
    """
    Evaluate model on validation samples (list of (text, label) tuples).
    """
    val_dataset = CategoryDatasetFromSamples(
        samples=val_samples,
        tokenizer=tokenizer
    )

    val_loader = DataLoader(
        val_dataset,
        batch_size=batch_size,
        shuffle=False
    )

    model.eval()

    total_loss = 0.0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for batch in val_loader:
            input_ids = batch["input_ids"].to(device)
            attention_mask = batch["attention_mask"].to(device)
            labels = batch["labels"].to(device)

            outputs = model(
                input_ids=input_ids,
                attention_mask=attention_mask,
                labels=labels
            )

            loss = outputs.loss
            logits = outputs.logits

            total_loss += loss.item()

            preds = torch.argmax(logits, dim=1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    avg_loss = total_loss / len(val_loader)
    acc = accuracy_score(all_labels, all_preds)
    macro_f1 = f1_score(all_labels, all_preds, average="macro")

    print("\n=== VALIDATION RESULTS ===")
    print(f"Loss:      {avg_loss:.4f}")
    print(f"Accuracy:  {acc:.4f}")
    print(f"Macro-F1:  {macro_f1:.4f}")

    return {
        "loss": avg_loss,
        "accuracy": acc,
        "macro_f1": macro_f1
    }

# %% [markdown]
# ## Save model and tokenizer
# Persist the trained weights and tokenizer configuration to disk so they can be reloaded without retraining.

# %%
def save_model(model, tokenizer, save_dir):
    os.makedirs(save_dir, exist_ok=True)
    model.save_pretrained(save_dir)
    tokenizer.save_pretrained(save_dir)

# %% [markdown]
# ## Load a saved model
# Recover the tokenizer and model from disk and move them to the active device for inference or evaluation.

# %%
def load_model(save_dir, device):
    tokenizer = BertTokenizer.from_pretrained(save_dir)
    model = BertForSequenceClassification.from_pretrained(save_dir)
    model.to(device)
    model.eval()
    return model, tokenizer

# %% [markdown]
# ## End-to-end training pipeline
# Define paths and device, instantiate tokenizer and dataset/dataloader, build the model and optimizer, run training with early stopping, save the best checkpoint, and finally evaluate the saved model on the chosen split.

# %%
def main():
    SAVE_DIR = "/content/drive/MyDrive/nlp_proiect/modele/bun_2"

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

    file_name = "/content/drive/MyDrive/nlp_proiect/nlp_data/eng_laptop_train_alltasks.jsonl"

    print("Splitting data into train (80%) and validation (20%)...")
    train_samples, val_samples = split_data_from_file(
        file_path=file_name,
        train_ratio=0.8,
        random_state=42
    )

    print(f"Train samples (80%): {len(train_samples)}")
    print(f"Validation samples (20%): {len(val_samples)}")

    class_weights = compute_class_weights(train_samples, NUM_LABELS).to(device)

    train_dataset = CategoryDatasetFromSamples(
        samples=train_samples,
        tokenizer=tokenizer
    )

    val_dataset = CategoryDatasetFromSamples(
        samples=val_samples,
        tokenizer=tokenizer
    )

    train_loader = DataLoader(
        train_dataset,
        batch_size=8,
        shuffle=True
    )

    val_loader = DataLoader(
        val_dataset,
        batch_size=8,
        shuffle=False
    )

    model = build_model(NUM_LABELS)
    model.to(device)

    optimizer = AdamW(
        model.parameters(),
        lr=3e-5,
        weight_decay=0.05
    )

    total_steps = len(train_loader) * 30
    warmup_steps = int(total_steps * 0.1)
    scheduler = get_linear_schedule_with_warmup(
        optimizer,
        num_warmup_steps=warmup_steps,
        num_training_steps=total_steps
    )

    criterion = nn.CrossEntropyLoss(weight=class_weights)

    print("\nTRAINING WITH VAL MONITORING (80/20)")
    best_val_f1 = train_model(
        model=model,
        train_loader=train_loader,
        val_loader=val_loader,
        optimizer=optimizer,
        scheduler=scheduler,
        criterion=criterion,
        device=device,
        epochs=35,
        patience=3
    )

    print(f"\nBest validation Macro-F1: {best_val_f1:.4f}")

    save_model(model, tokenizer, SAVE_DIR)

    # Evaluate on remaining 20% of data
    print("\nFINAL EVALUATION ON 20% VALIDATION SET")
    evaluate_on_samples(
        model=model,
        tokenizer=tokenizer,
        val_samples=val_samples,
        device=device,
        batch_size=8
    )

# %%
if __name__ == "__main__":
    main()
# Out:
# Splitting data into train (80%) and validation (20%)...
# ⚠ Stratification failed (some classes have too few samples), using regular split
# Train samples (80%): 4618
# Validation samples (20%): 1155
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# TRAINING WITH VAL MONITORING (80/20)
# [Epoch 1] Train Loss: 5.4258 | Train Acc: 0.0048 | Train Macro-F1: 0.0006 || Val Loss: 4.9643 | Val Acc: 0.0199 | Val Macro-F1: 0.0011
# [Epoch 2] Train Loss: 4.5988 | Train Acc: 0.0784 | Train Macro-F1: 0.0183 || Val Loss: 4.4677 | Val Acc: 0.1628 | Val Macro-F1: 0.0421
# [Epoch 3] Train Loss: 3.7936 | Train Acc: 0.3149 | Train Macro-F1: 0.0722 || Val Loss: 3.5926 | Val Acc: 0.4130 | Val Macro-F1: 0.1155
# [Epoch 4] Train Loss: 2.9864 | Train Acc: 0.4465 | Train Macro-F1: 0.1340 || Val Loss: 3.1067 | Val Acc: 0.4424 | Val Macro-F1: 0.1490
# [Epoch 5] Train Loss: 2.3891 | Train Acc: 0.5288 | Train Macro-F1: 0.1970 || Val Loss: 2.7612 | Val Acc: 0.4918 | Val Macro-F1: 0.1966
# [Epoch 6] Train Loss: 2.0045 | Train Acc: 0.5760 | Train Macro-F1: 0.2551 || Val Loss: 2.6845 | Val Acc: 0.5186 | Val Macro-F1: 0.2163
# [Epoch 7] Train Loss: 1.6937 | Train Acc: 0.6464 | Train Macro-F1: 0.3141 || Val Loss: 2.6461 | Val Acc: 0.5506 | Val Macro-F1: 0.2503
# [Epoch 8] Train Loss: 1.4477 | Train Acc: 0.7280 | Train Macro-F1: 0.4033 || Val Loss: 2.5144 | Val Acc: 0.5766 | Val Macro-F1: 0.2731
# [Epoch 9] Train Loss: 1.1798 | Train Acc: 0.7854 | Train Macro-F1: 0.4992 || Val Loss: 2.5074 | Val Acc: 0.6026 | Val Macro-F1: 0.3169
# [Epoch 10] Train Loss: 0.9628 | Train Acc: 0.8391 | Train Macro-F1: 0.5594 || Val Loss: 2.4714 | Val Acc: 0.5723 | Val Macro-F1: 0.3145
#   - No validation improvement for 1/3 epochs
# [Epoch 11] Train Loss: 0.7471 | Train Acc: 0.8681 | Train Macro-F1: 0.6430 || Val Loss: 2.5372 | Val Acc: 0.6026 | Val Macro-F1: 0.3225
# [Epoch 12] Train Loss: 0.6117 | Train Acc: 0.9008 | Train Macro-F1: 0.7326 || Val Loss: 2.5687 | Val Acc: 0.6078 | Val Macro-F1: 0.3248
# [Epoch 13] Train Loss: 0.4615 | Train Acc: 0.9266 | Train Macro-F1: 0.7577 || Val Loss: 2.5193 | Val Acc: 0.6026 | Val Macro-F1: 0.3312
# [Epoch 14] Train Loss: 0.3655 | Train Acc: 0.9413 | Train Macro-F1: 0.8082 || Val Loss: 2.6479 | Val Acc: 0.6173 | Val Macro-F1: 0.3544
# [Epoch 15] Train Loss: 0.2950 | Train Acc: 0.9539 | Train Macro-F1: 0.8522 || Val Loss: 2.6540 | Val Acc: 0.6017 | Val Macro-F1: 0.3486
#   - No validation improvement for 1/3 epochs
# [Epoch 16] Train Loss: 0.2405 | Train Acc: 0.9604 | Train Macro-F1: 0.8878 || Val Loss: 2.7261 | Val Acc: 0.6286 | Val Macro-F1: 0.3799
# [Epoch 17] Train Loss: 0.2150 | Train Acc: 0.9651 | Train Macro-F1: 0.8869 || Val Loss: 2.6928 | Val Acc: 0.6104 | Val Macro-F1: 0.3687
#   - No validation improvement for 1/3 epochs
# [Epoch 18] Train Loss: 0.1684 | Train Acc: 0.9723 | Train Macro-F1: 0.9731 || Val Loss: 2.7827 | Val Acc: 0.6225 | Val Macro-F1: 0.3640
#   - No validation improvement for 2/3 epochs
# [Epoch 19] Train Loss: 0.1437 | Train Acc: 0.9799 | Train Macro-F1: 0.9742 || Val Loss: 2.7972 | Val Acc: 0.6312 | Val Macro-F1: 0.3932
# [Epoch 20] Train Loss: 0.1148 | Train Acc: 0.9820 | Train Macro-F1: 0.9769 || Val Loss: 2.8533 | Val Acc: 0.6294 | Val Macro-F1: 0.3863
#   - No validation improvement for 1/3 epochs
# [Epoch 21] Train Loss: 0.1014 | Train Acc: 0.9822 | Train Macro-F1: 0.9860 || Val Loss: 2.9290 | Val Acc: 0.6147 | Val Macro-F1: 0.3704
#   - No validation improvement for 2/3 epochs
# [Epoch 22] Train Loss: 0.0796 | Train Acc: 0.9892 | Train Macro-F1: 0.9937 || Val Loss: 2.9762 | Val Acc: 0.6225 | Val Macro-F1: 0.3852
#   - No validation improvement for 3/3 epochs
# !! Early stopping at epoch 22. Best Val Macro-F1: 0.3932
#
# Best validation Macro-F1: 0.3932
#
# FINAL EVALUATION ON 20% VALIDATION SET
#
# === VALIDATION RESULTS ===
# Loss:      1.7477
# Accuracy:  0.6312
# Macro-F1:  0.3932

# %%
### PT INTEGRARE IN PROIECT


SAVE_DIR = "task_3_saved_model"

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model, tokenizer = load_model(SAVE_DIR, device)

text = "the trackpad works well and the screen display is great too ."
aspect = "trackpad"
opinion = "well"
va = "6.50#6.62"

category = predict_category(model, tokenizer, device, text, aspect, opinion, va)

print(f"Predicted category: {category}")
# Out:
# Predicted category: HARDWARE#OPERATION_PERFORMANCE

# %%
def generate_predictions(input_file, output_file, model, tokenizer, device, category2id, id2category):
    """
    Citește fișierul JSONL cu Quadruplets (Aspect + Opinion + VA),
    prezice Category pentru fiecare quadruplet,
    și scrie rezultatele în format JSON complet.
    """

    predictions = []

    with open(input_file, encoding="utf-8") as f:
        for line in f:
            data = json.loads(line)
            text = data["Text"]
            sample_id = data.get("ID", "")

            quadruplets = []

            # Preluăm Quadruplets din fișierul de intrare (conține Aspect + Opinion + VA)
            if "Quadruplets" in data and data["Quadruplets"]:
                for quad in data["Quadruplets"]:
                    aspect = quad.get("Aspect", "NULL")
                    opinion = quad.get("Opinion", "NULL")
                    va = quad.get("VA", "5.00#5.00")

                    # Fac predicția pentru Category folosind valorile din fișier
                    predicted_category = predict_category(
                        model, tokenizer, device, text, aspect, opinion, va
                    )

                    quadruplets.append({
                        "Aspect": aspect,
                        "Category": predicted_category,
                        "Opinion": opinion,
                        "VA": va
                    })

            # Fallback: dacă avem Quadruplet (format singular)
            elif "Quadruplet" in data and data["Quadruplet"]:
                for quad in data["Quadruplet"]:
                    aspect = quad.get("Aspect", "NULL")
                    opinion = quad.get("Opinion", "NULL")
                    va = quad.get("VA", "5.00#5.00")

                    # Fac predicția pentru Category
                    predicted_category = predict_category(
                        model, tokenizer, device, text, aspect, opinion, va
                    )

                    quadruplets.append({
                        "Aspect": aspect,
                        "Category": predicted_category,
                        "Opinion": opinion,
                        "VA": va
                    })

            else:
                # Pentru cazul fără niciun Quadruplet, cream placeholder
                quadruplets.append({
                    "Aspect": "NULL",
                    "Category": "OUT_OF_SCOPE#GENERAL",
                    "Opinion": "NULL",
                    "VA": "5.00#5.00"
                })

            predictions.append({
                "ID": sample_id,
                "Quadruplet": quadruplets
            })

    # Scriu predicțiile în fișierul JSON
    with open(output_file, "w", encoding="utf-8") as f:
        for pred in predictions:
            f.write(json.dumps(pred) + "\n")

    print(f"✓ Predicții generate și salvate în: {output_file}")
    print(f"Total instanțe procesate: {len(predictions)}")
    return predictions



SAVE_DIR = "task_3_saved_model"

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model, tokenizer = load_model(SAVE_DIR, device)

# Generez predicții pentru test_pred_with_va.jsonl
generate_predictions(
    input_file="test_pred_with_va.jsonl",
    output_file="submit_data_task3.json",
    model=model,
    tokenizer=tokenizer,
    device=device,
    category2id=category2id,
    id2category=id2category
)
# Out:
# ✓ Predicții generate și salvate în: submit_data_task3.json
# Total instanțe procesate: 200
# [{'ID': 'lap26_asqp_dev_1',
#   'Quadruplet': [{'Aspect': 'perforemce',
#     'Category': 'SHIPPING#PRICE',
#     'Opinion': 'great',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'price',
#     'Category': 'LAPTOP#PRICE',
#     'Opinion': 'great',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_2',
#   'Quadruplet': [{'Aspect': 'display',
#     'Category': 'DISPLAY#OPERATION_PERFORMANCE',
#     'Opinion': 'Very bright',
#     'VA': '6.99#6.97'},
#    {'Aspect': 'color gamut',
#     'Category': 'DISPLAY#DESIGN_FEATURES',
#     'Opinion': 'wide',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_3',
#   'Quadruplet': [{'Aspect': 'Battery life',
#     'Category': 'BATTERY#OPERATION_PERFORMANCE',
#     'Opinion': 'bad',
#     'VA': '3.61#6.20'}]},
#  {'ID': 'lap26_asqp_dev_4',
#   'Quadruplet': [{'Aspect': 'Chromebook',
#     'Category': 'LAPTOP#DESIGN_FEATURES',
#     'Opinion': 'very clean',
#     'VA': '5.00#5.56'},
#    {'Aspect': ' Chromebook',
#     'Category': 'LAPTOP#DESIGN_FEATURES',
#     'Opinion': 'NULL',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_5',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'DISPLAY#DESIGN_FEATURES',
#     'Opinion': 'very bright',
#     'VA': '6.99#6.97'},
#    {'Aspect': 'screen',
#     'Category': 'DISPLAY#DESIGN_FEATURES',
#     'Opinion': 'clear',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_6',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'like',
#     'VA': '5.00#4.80'},
#    {'Aspect': 'sound quality',
#     'Category': 'MULTIMEDIA_DEVICES#QUALITY',
#     'Opinion': 'excellent',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_7',
#   'Quadruplet': [{'Aspect': 'video card',
#     'Category': 'MEMORY#GENERAL',
#     'Opinion': 'very much worth',
#     'VA': '6.99#6.97'}]},
#  {'ID': 'lap26_asqp_dev_8',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#PRICE',
#     'Opinion': 'Great',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_9',
#   'Quadruplet': [{'Aspect': 'Zenbook',
#     'Category': 'LAPTOP#OPERATION_PERFORMANCE',
#     'Opinion': 'powerful',
#     'VA': '5.00#4.80'},
#    {'Aspect': 'storage',
#     'Category': 'HARD_DISK#GENERAL',
#     'Opinion': 'NULL',
#     'VA': '5.00#4.80'},
#    {'Aspect': 'memory',
#     'Category': 'MEMORY#GENERAL',
#     'Opinion': 'NULL',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_10',
#   'Quadruplet': [{'Aspect': 'RAM',
#     'Category': 'MEMORY#DESIGN_FEATURES',
#     'Opinion': 'NULL',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_11',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'best',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_12',
#   'Quadruplet': [{'Aspect': 'Chrome OS',
#     'Category': 'OS#OPERATION_PERFORMANCE',
#     'Opinion': 'really great',
#     'VA': '6.99#6.97'}]},
#  {'ID': 'lap26_asqp_dev_13',
#   'Quadruplet': [{'Aspect': 'screen',
#     'Category': 'DISPLAY#DESIGN_FEATURES',
#     'Opinion': 'huge',
#     'VA': '5.00#4.80'},
#    {'Aspect': 'laptop',
#     'Category': 'LAPTOP#DESIGN_FEATURES',
#     'Opinion': 'very lightweight',
#     'VA': '5.00#5.56'}]},
#  {'ID': 'lap26_asqp_dev_14',
#   'Quadruplet': [{'Aspect': 'trackpad',
#     'Category': 'HARDWARE#GENERAL',
#     'Opinion': 'decent',
#     'VA': '5.00#4.80'},
#    {'Aspect': 'laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'probably the best',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_15',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'loving',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_16',
#   'Quadruplet': [{'Aspect': 'Chromebook',
#     'Category': 'LAPTOP#OPERATION_PERFORMANCE',
#     'Opinion': 'really like',
#     'VA': '5.00#5.56'},
#    {'Aspect': ' Chromebook',
#     'Category': 'LAPTOP#DESIGN_FEATURES',
#     'Opinion': 'sleek',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_17',
#   'Quadruplet': [{'Aspect': 'processing speed',
#     'Category': 'CPU#OPERATION_PERFORMANCE',
#     'Opinion': 'spectacular',
#     'VA': '5.00#4.80'},
#    {'Aspect': 'laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'great',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_18',
#   'Quadruplet': [{'Aspect': 'replaceable battery',
#     'Category': 'BATTERY#QUALITY',
#     'Opinion': 'light',
#     'VA': '5.00#4.80'},
#    {'Aspect': 'battery',
#     'Category': 'BATTERY#QUALITY',
#     'Opinion': 'much thinner',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_19',
#   'Quadruplet': [{'Aspect': 'mouse',
#     'Category': 'KEYBOARD#GENERAL',
#     'Opinion': 'TERRIBLE',
#     'VA': '3.61#6.20'}]},
#  {'ID': 'lap26_asqp_dev_20',
#   'Quadruplet': [{'Aspect': 'Keyboard',
#     'Category': 'KEYBOARD#DESIGN_FEATURES',
#     'Opinion': 'solid',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'Keyboard',
#     'Category': 'KEYBOARD#DESIGN_FEATURES',
#     'Opinion': 'ergonomically',
#     'VA': '5.00#4.80'},
#    {'Aspect': 'number pad',
#     'Category': 'KEYBOARD#USABILITY',
#     'Opinion': 'very useful',
#     'VA': '5.00#5.56'}]},
#  {'ID': 'lap26_asqp_dev_21',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#USABILITY',
#     'Opinion': 'Pretty simple',
#     'VA': '5.00#4.80'},
#    {'Aspect': 'laptop',
#     'Category': 'LAPTOP#USABILITY',
#     'Opinion': 'basic',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_22',
#   'Quadruplet': [{'Aspect': 'NULL',
#     'Category': 'LAPTOP#PRICE',
#     'Opinion': 'good',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_23',
#   'Quadruplet': [{'Aspect': 'battery life',
#     'Category': 'BATTERY#QUALITY',
#     'Opinion': 'Poor',
#     'VA': '3.61#6.20'},
#    {'Aspect': 'battery life',
#     'Category': 'BATTERY#QUALITY',
#     'Opinion': 'fair',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_24',
#   'Quadruplet': [{'Aspect': 'computer',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'NULL',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_25',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'extremely nice',
#     'VA': '6.99#6.97'},
#    {'Aspect': 'laptop',
#     'Category': 'LAPTOP#PRICE',
#     'Opinion': 'just ridiculously good',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_26',
#   'Quadruplet': [{'Aspect': 'Laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'NULL',
#     'VA': '5.00#4.80'},
#    {'Aspect': 'keyboard',
#     'Category': 'KEYBOARD#QUALITY',
#     'Opinion': 'NULL',
#     'VA': '5.00#4.80'},
#    {'Aspect': 'computer',
#     'Category': 'LAPTOP#QUALITY',
#     'Opinion': 'dirty',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_27',
#   'Quadruplet': [{'Aspect': 'fans',
#     'Category': 'FANS_COOLING#OPERATION_PERFORMANCE',
#     'Opinion': 'super huge',
#     'VA': '5.00#5.56'}]},
#  {'ID': 'lap26_asqp_dev_28',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'nice',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_29',
#   'Quadruplet': [{'Aspect': 'computer',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'Great',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'computer',
#     'Category': 'LAPTOP#OPERATION_PERFORMANCE',
#     'Opinion': 'very fast',
#     'VA': '6.99#6.97'}]},
#  {'ID': 'lap26_asqp_dev_30',
#   'Quadruplet': [{'Aspect': 'ASUS products',
#     'Category': 'COMPANY#GENERAL',
#     'Opinion': 'love',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_31',
#   'Quadruplet': [{'Aspect': 'processor',
#     'Category': 'CPU#OPERATION_PERFORMANCE',
#     'Opinion': 'Fast',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'screen',
#     'Category': 'DISPLAY#DESIGN_FEATURES',
#     'Opinion': 'clear',
#     'VA': '5.00#4.80'},
#    {'Aspect': 'battery life',
#     'Category': 'BATTERY#QUALITY',
#     'Opinion': 'long',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_32',
#   'Quadruplet': [{'Aspect': 'notebook',
#     'Category': 'LAPTOP#DESIGN_FEATURES',
#     'Opinion': 'very happy',
#     'VA': '6.99#6.97'}]},
#  {'ID': 'lap26_asqp_dev_33',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#OPERATION_PERFORMANCE',
#     'Opinion': 'nicely',
#     'VA': '5.00#4.80'},
#    {'Aspect': 'laptop',
#     'Category': 'LAPTOP#USABILITY',
#     'Opinion': 'enjoy',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_34',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'love',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'enjoying',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_35',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'amazing',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_36',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#OPERATION_PERFORMANCE',
#     'Opinion': 'great',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'laptop',
#     'Category': 'LAPTOP#OPERATION_PERFORMANCE',
#     'Opinion': 'great',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_37',
#   'Quadruplet': [{'Aspect': 'keyboard',
#     'Category': 'KEYBOARD#DESIGN_FEATURES',
#     'Opinion': 'very well',
#     'VA': '5.00#5.56'},
#    {'Aspect': 'keyboard',
#     'Category': 'KEYBOARD#DESIGN_FEATURES',
#     'Opinion': 'comfortable',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_38',
#   'Quadruplet': [{'Aspect': 'Trackpad',
#     'Category': 'HARDWARE#OPERATION_PERFORMANCE',
#     'Opinion': 'horribly',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_39',
#   'Quadruplet': [{'Aspect': 'Screen',
#     'Category': 'DISPLAY#OPERATION_PERFORMANCE',
#     'Opinion': 'bright',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'display',
#     'Category': 'DISPLAY#OPERATION_PERFORMANCE',
#     'Opinion': 'rich',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_40',
#   'Quadruplet': [{'Aspect': 'Camera quality',
#     'Category': 'DISPLAY#QUALITY',
#     'Opinion': 'not great',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_41',
#   'Quadruplet': [{'Aspect': 'computer',
#     'Category': 'LAPTOP#OPERATION_PERFORMANCE',
#     'Opinion': 'NULL',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_42',
#   'Quadruplet': [{'Aspect': 'computer',
#     'Category': 'LAPTOP#DESIGN_FEATURES',
#     'Opinion': 'awesome',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'touchscreen',
#     'Category': 'DISPLAY#GENERAL',
#     'Opinion': 'great',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_43',
#   'Quadruplet': [{'Aspect': 'NULL',
#     'Category': 'LAPTOP#DESIGN_FEATURES',
#     'Opinion': 'much nicer',
#     'VA': '5.00#4.80'},
#    {'Aspect': 'NULL',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'absolutely stunning',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_44',
#   'Quadruplet': [{'Aspect': 'device',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'Great',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'device',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'probably one of the best',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_45',
#   'Quadruplet': [{'Aspect': 'screen',
#     'Category': 'DISPLAY#GENERAL',
#     'Opinion': 'nice',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'key pad',
#     'Category': 'KEYBOARD#GENERAL',
#     'Opinion': 'NULL',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_46',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#DESIGN_FEATURES',
#     'Opinion': 'lightweight',
#     'VA': '5.00#4.80'},
#    {'Aspect': 'laptop',
#     'Category': 'LAPTOP#DESIGN_FEATURES',
#     'Opinion': 'NULL',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_47',
#   'Quadruplet': [{'Aspect': 'keys',
#     'Category': 'KEYBOARD#OPERATION_PERFORMANCE',
#     'Opinion': 'responsive',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_48',
#   'Quadruplet': [{'Aspect': 'graphics',
#     'Category': 'GRAPHICS#GENERAL',
#     'Opinion': 'clear',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_49',
#   'Quadruplet': [{'Aspect': 'gaming laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'excellent',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_50',
#   'Quadruplet': [{'Aspect': 'warranty',
#     'Category': 'WARRANTY#GENERAL',
#     'Opinion': 'no good',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_51',
#   'Quadruplet': [{'Aspect': 'Chromebook',
#     'Category': 'LAPTOP#OPERATION_PERFORMANCE',
#     'Opinion': 'just fine',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_52',
#   'Quadruplet': [{'Aspect': 'Chromebook',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'surprisingly very nice',
#     'VA': '6.99#6.97'}]},
#  {'ID': 'lap26_asqp_dev_53',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'best',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_54',
#   'Quadruplet': [{'Aspect': 'Battery life',
#     'Category': 'BATTERY#OPERATION_PERFORMANCE',
#     'Opinion': 'not great',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_55',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'Love',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_56',
#   'Quadruplet': [{'Aspect': 'battery',
#     'Category': 'BATTERY#QUALITY',
#     'Opinion': 'better',
#     'VA': '5.00#4.80'},
#    {'Aspect': 'cooling',
#     'Category': 'FANS_COOLING#GENERAL',
#     'Opinion': 'better',
#     'VA': '5.00#4.80'},
#    {'Aspect': 'benchmark tests',
#     'Category': 'LAPTOP#QUALITY',
#     'Opinion': 'better',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_57',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'great',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_58',
#   'Quadruplet': [{'Aspect': 'computer',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'absolutely love',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_59',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#OPERATION_PERFORMANCE',
#     'Opinion': 'powerful',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_60',
#   'Quadruplet': [{'Aspect': 'computer',
#     'Category': 'LAPTOP#USABILITY',
#     'Opinion': 'NULL',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_61',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#OPERATION_PERFORMANCE',
#     'Opinion': 'fast',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'laptop',
#     'Category': 'LAPTOP#OPERATION_PERFORMANCE',
#     'Opinion': 'reliable',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_62',
#   'Quadruplet': [{'Aspect': 'processor',
#     'Category': 'CPU#OPERATION_PERFORMANCE',
#     'Opinion': 'Fast',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'Core 2 Duo',
#     'Category': 'CPU#OPERATION_PERFORMANCE',
#     'Opinion': 'great',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_63',
#   'Quadruplet': [{'Aspect': 'Windows 10',
#     'Category': 'OS#OPERATION_PERFORMANCE',
#     'Opinion': 'extremely frustrating',
#     'VA': '5.00#5.56'}]},
#  {'ID': 'lap26_asqp_dev_64',
#   'Quadruplet': [{'Aspect': 'ScreenPad',
#     'Category': 'DISPLAY#GENERAL',
#     'Opinion': 'delight',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_65',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#DESIGN_FEATURES',
#     'Opinion': 'Great',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_66',
#   'Quadruplet': [{'Aspect': 'computer',
#     'Category': 'LAPTOP#DESIGN_FEATURES',
#     'Opinion': 'like',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_67',
#   'Quadruplet': [{'Aspect': 'Windows 8.1',
#     'Category': 'OS#GENERAL',
#     'Opinion': 'really love',
#     'VA': '6.99#6.97'},
#    {'Aspect': 'Windows 8.1',
#     'Category': 'OS#OPERATION_PERFORMANCE',
#     'Opinion': 'nicely',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_68',
#   'Quadruplet': [{'Aspect': 'screen',
#     'Category': 'DISPLAY#GENERAL',
#     'Opinion': 'love',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_69',
#   'Quadruplet': [{'Aspect': 'Chromebook',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'amazingly good',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_70',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'absolutely love',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_71',
#   'Quadruplet': [{'Aspect': 'SSD',
#     'Category': 'HARD_DISK#OPERATION_PERFORMANCE',
#     'Opinion': 'very fast',
#     'VA': '6.99#6.97'},
#    {'Aspect': 'RAM memory',
#     'Category': 'MEMORY#OPERATION_PERFORMANCE',
#     'Opinion': 'responsive',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_72',
#   'Quadruplet': [{'Aspect': 'CPU',
#     'Category': 'CPU#OPERATION_PERFORMANCE',
#     'Opinion': 'plenty fast',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_73',
#   'Quadruplet': [{'Aspect': 'keyboard',
#     'Category': 'KEYBOARD#GENERAL',
#     'Opinion': 'nice',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'screen',
#     'Category': 'DISPLAY#GENERAL',
#     'Opinion': 'nice',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'sounds',
#     'Category': 'MULTIMEDIA_DEVICES#OPERATION_PERFORMANCE',
#     'Opinion': 'nice',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_74',
#   'Quadruplet': [{'Aspect': 'Sound',
#     'Category': 'MULTIMEDIA_DEVICES#OPERATION_PERFORMANCE',
#     'Opinion': 'awesome',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_75',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#OPERATION_PERFORMANCE',
#     'Opinion': 'NULL',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_76',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#OPERATION_PERFORMANCE',
#     'Opinion': 'very powerful',
#     'VA': '5.00#5.56'},
#    {'Aspect': 'laptop',
#     'Category': 'LAPTOP#OPERATION_PERFORMANCE',
#     'Opinion': 'fast',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_77',
#   'Quadruplet': [{'Aspect': 'netbook',
#     'Category': 'LAPTOP#OPERATION_PERFORMANCE',
#     'Opinion': 'pitiful',
#     'VA': '5.00#4.80'},
#    {'Aspect': 'RAM',
#     'Category': 'MEMORY#DESIGN_FEATURES',
#     'Opinion': 'pitiful',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_78',
#   'Quadruplet': [{'Aspect': 'touch screen',
#     'Category': 'DISPLAY#DESIGN_FEATURES',
#     'Opinion': 'very large',
#     'VA': '5.00#5.56'}]},
#  {'ID': 'lap26_asqp_dev_79',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'pleasantly',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_80',
#   'Quadruplet': [{'Aspect': 'computer',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'Nice',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'computer',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'no problem',
#     'VA': '3.61#6.20'}]},
#  {'ID': 'lap26_asqp_dev_81',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'worst',
#     'VA': '3.61#6.20'}]},
#  {'ID': 'lap26_asqp_dev_82',
#   'Quadruplet': [{'Aspect': 'keyboard',
#     'Category': 'KEYBOARD#DESIGN_FEATURES',
#     'Opinion': 'wide',
#     'VA': '5.00#4.80'},
#    {'Aspect': 'keyboard',
#     'Category': 'KEYBOARD#USABILITY',
#     'Opinion': 'comfortable',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_83',
#   'Quadruplet': [{'Aspect': 'screen',
#     'Category': 'DISPLAY#DESIGN_FEATURES',
#     'Opinion': 'beautiful',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_84',
#   'Quadruplet': [{'Aspect': 'HP Chromebook',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'great',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_85',
#   'Quadruplet': [{'Aspect': 'NULL',
#     'Category': 'LAPTOP#DESIGN_FEATURES',
#     'Opinion': 'quite light',
#     'VA': '5.00#5.56'},
#    {'Aspect': 'NULL',
#     'Category': 'LAPTOP#PORTABILITY',
#     'Opinion': 'easy',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_86',
#   'Quadruplet': [{'Aspect': 'picture',
#     'Category': 'DISPLAY#QUALITY',
#     'Opinion': 'Great',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'sound',
#     'Category': 'MULTIMEDIA_DEVICES#OPERATION_PERFORMANCE',
#     'Opinion': 'nice',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_87',
#   'Quadruplet': [{'Aspect': 'concept',
#     'Category': 'HARDWARE#GENERAL',
#     'Opinion': 'Great',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'touch screen functionality',
#     'Category': 'DISPLAY#OPERATION_PERFORMANCE',
#     'Opinion': 'love',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_88',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#PRICE',
#     'Opinion': 'good',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_89',
#   'Quadruplet': [{'Aspect': 'device',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'NULL',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_90',
#   'Quadruplet': [{'Aspect': 'battery life',
#     'Category': 'BATTERY#QUALITY',
#     'Opinion': 'awful',
#     'VA': '3.61#6.20'}]},
#  {'ID': 'lap26_asqp_dev_91',
#   'Quadruplet': [{'Aspect': 'HP laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'good',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_92',
#   'Quadruplet': [{'Aspect': 'NULL',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'love',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'NULL',
#     'Category': 'LAPTOP#OPERATION_PERFORMANCE',
#     'Opinion': 'really fast',
#     'VA': '6.99#6.97'},
#    {'Aspect': 'NULL',
#     'Category': 'HARDWARE#OPERATION_PERFORMANCE',
#     'Opinion': 'super sharp',
#     'VA': '6.99#6.97'}]},
#  {'ID': 'lap26_asqp_dev_93',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'fantastic',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_94',
#   'Quadruplet': [{'Aspect': 'NULL',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'love',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'Asus',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'love',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_95',
#   'Quadruplet': [{'Aspect': 'computer',
#     'Category': 'LAPTOP#OPERATION_PERFORMANCE',
#     'Opinion': 'NULL',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_96',
#   'Quadruplet': [{'Aspect': 'Battery life',
#     'Category': 'BATTERY#GENERAL',
#     'Opinion': 'good',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_97',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#DESIGN_FEATURES',
#     'Opinion': 'NULL',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_98',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#DESIGN_FEATURES',
#     'Opinion': 'super light',
#     'VA': '5.00#5.56'}]},
#  {'ID': 'lap26_asqp_dev_99',
#   'Quadruplet': [{'Aspect': 'computer',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'love',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_100',
#   'Quadruplet': [{'Aspect': 'screen',
#     'Category': 'DISPLAY#DESIGN_FEATURES',
#     'Opinion': 'Large',
#     'VA': '5.00#4.80'},
#    {'Aspect': 'storage',
#     'Category': 'HARD_DISK#GENERAL',
#     'Opinion': 'lots',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_101',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'WORST',
#     'VA': '3.61#6.20'}]},
#  {'ID': 'lap26_asqp_dev_102',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#OPERATION_PERFORMANCE',
#     'Opinion': 'FAST',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'keyboard',
#     'Category': 'KEYBOARD#GENERAL',
#     'Opinion': 'love',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_103',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#PRICE',
#     'Opinion': 'inexpensive',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_104',
#   'Quadruplet': [{'Aspect': 'computer',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'amazing',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_105',
#   'Quadruplet': [{'Aspect': 'track pad',
#     'Category': 'KEYBOARD#DESIGN_FEATURES',
#     'Opinion': 'beautiful',
#     'VA': '5.00#4.80'},
#    {'Aspect': 'track pad',
#     'Category': 'KEYBOARD#DESIGN_FEATURES',
#     'Opinion': 'super large',
#     'VA': '5.00#5.56'}]},
#  {'ID': 'lap26_asqp_dev_106',
#   'Quadruplet': [{'Aspect': 'pc',
#     'Category': 'LAPTOP#OPERATION_PERFORMANCE',
#     'Opinion': 'slowest',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_107',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'really like',
#     'VA': '5.00#5.56'},
#    {'Aspect': 'laptop',
#     'Category': 'LAPTOP#OPERATION_PERFORMANCE',
#     'Opinion': 'powerful',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_108',
#   'Quadruplet': [{'Aspect': 'NULL',
#     'Category': 'LAPTOP#QUALITY',
#     'Opinion': 'very solid',
#     'VA': '6.99#6.97'}]},
#  {'ID': 'lap26_asqp_dev_109',
#   'Quadruplet': [{'Aspect': 'web cam',
#     'Category': 'HARDWARE#OPERATION_PERFORMANCE',
#     'Opinion': 'unnessecarely hard',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_110',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#PRICE',
#     'Opinion': 'SOOOO much better',
#     'VA': '5.00#4.80'},
#    {'Aspect': 'Windows PC',
#     'Category': 'LAPTOP#PRICE',
#     'Opinion': 'SOOOO much better',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_111',
#   'Quadruplet': [{'Aspect': 'touch screen',
#     'Category': 'DISPLAY#OPERATION_PERFORMANCE',
#     'Opinion': 'very responsive',
#     'VA': '5.00#5.56'},
#    {'Aspect': 'touch screen',
#     'Category': 'DISPLAY#OPERATION_PERFORMANCE',
#     'Opinion': 'accurate',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_112',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'spectacular',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_113',
#   'Quadruplet': [{'Aspect': 'brand in gaming',
#     'Category': 'COMPANY#GENERAL',
#     'Opinion': 'absolutely best',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_114',
#   'Quadruplet': [{'Aspect': 'display',
#     'Category': 'DISPLAY#OPERATION_PERFORMANCE',
#     'Opinion': 'clear',
#     'VA': '5.00#4.80'},
#    {'Aspect': 'display',
#     'Category': 'DISPLAY#OPERATION_PERFORMANCE',
#     'Opinion': 'bright',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_115',
#   'Quadruplet': [{'Aspect': 'charging cord',
#     'Category': 'POWER_SUPPLY#DESIGN_FEATURES',
#     'Opinion': 'decent',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_116',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#OPERATION_PERFORMANCE',
#     'Opinion': 'Not great',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'laptop',
#     'Category': 'LAPTOP#PRICE',
#     'Opinion': 'inexpensive',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_117',
#   'Quadruplet': [{'Aspect': 'computer',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'very pleased',
#     'VA': '5.00#5.56'}]},
#  {'ID': 'lap26_asqp_dev_118',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'love',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'laptop',
#     'Category': 'LAPTOP#OPERATION_PERFORMANCE',
#     'Opinion': 'amazed',
#     'VA': '5.00#4.80'},
#    {'Aspect': 'laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'love',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_119',
#   'Quadruplet': [{'Aspect': 'Laptop',
#     'Category': 'LAPTOP#OPERATION_PERFORMANCE',
#     'Opinion': 'great',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_120',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#QUALITY',
#     'Opinion': 'poor',
#     'VA': '3.61#6.20'}]},
#  {'ID': 'lap26_asqp_dev_121',
#   'Quadruplet': [{'Aspect': 'monitor',
#     'Category': 'DISPLAY#GENERAL',
#     'Opinion': 'nice',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'monitor',
#     'Category': 'DISPLAY#DESIGN_FEATURES',
#     'Opinion': 'bright',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'monitor',
#     'Category': 'DISPLAY#USABILITY',
#     'Opinion': 'very easy',
#     'VA': '5.00#5.56'}]},
#  {'ID': 'lap26_asqp_dev_122',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'worst',
#     'VA': '3.61#6.20'}]},
#  {'ID': 'lap26_asqp_dev_123',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'Nice',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_124',
#   'Quadruplet': [{'Aspect': 'SSDH',
#     'Category': 'HARD_DISK#QUALITY',
#     'Opinion': 'love',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'SDH',
#     'Category': 'LAPTOP#OPERATION_PERFORMANCE',
#     'Opinion': 'love',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'SDH',
#     'Category': 'LAPTOP#OPERATION_PERFORMANCE',
#     'Opinion': 'love',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_125',
#   'Quadruplet': [{'Aspect': 'Laptop speakers',
#     'Category': 'MULTIMEDIA_DEVICES#GENERAL',
#     'Opinion': "n't great",
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_126',
#   'Quadruplet': [{'Aspect': 'processor',
#     'Category': 'CPU#OPERATION_PERFORMANCE',
#     'Opinion': 'impressive',
#     'VA': '5.00#4.80'},
#    {'Aspect': 'graphics quality',
#     'Category': 'GRAPHICS#OPERATION_PERFORMANCE',
#     'Opinion': 'great',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_127',
#   'Quadruplet': [{'Aspect': 'Chromebook',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'great',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_128',
#   'Quadruplet': [{'Aspect': 'processor',
#     'Category': 'CPU#GENERAL',
#     'Opinion': 'good',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'RAM',
#     'Category': 'MEMORY#GENERAL',
#     'Opinion': 'good',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'hard drives read/write speed',
#     'Category': 'HARD_DISK#OPERATION_PERFORMANCE',
#     'Opinion': 'defiantly',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_129',
#   'Quadruplet': [{'Aspect': 'NULL',
#     'Category': 'LAPTOP#DESIGN_FEATURES',
#     'Opinion': 'good',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'display',
#     'Category': 'DISPLAY#GENERAL',
#     'Opinion': 'good',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'spec parts',
#     'Category': 'HARDWARE#OPERATION_PERFORMANCE',
#     'Opinion': 'well',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_130',
#   'Quadruplet': [{'Aspect': 'keyboard',
#     'Category': 'KEYBOARD#USABILITY',
#     'Opinion': 'comfortable',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_131',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#OPERATION_PERFORMANCE',
#     'Opinion': 'very impressed',
#     'VA': '5.00#5.56'}]},
#  {'ID': 'lap26_asqp_dev_132',
#   'Quadruplet': [{'Aspect': 'notebook computer',
#     'Category': 'LAPTOP#DESIGN_FEATURES',
#     'Opinion': 'very thin',
#     'VA': '5.00#5.56'},
#    {'Aspect': 'notebook computer',
#     'Category': 'LAPTOP#DESIGN_FEATURES',
#     'Opinion': 'dainty',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_133',
#   'Quadruplet': [{'Aspect': 'mouse pad',
#     'Category': 'KEYBOARD#OPERATION_PERFORMANCE',
#     'Opinion': 'not as responsive',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_134',
#   'Quadruplet': [{'Aspect': 'battery life',
#     'Category': 'BATTERY#GENERAL',
#     'Opinion': 'OUTSTANDING',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_135',
#   'Quadruplet': [{'Aspect': 'size',
#     'Category': 'LAPTOP#DESIGN_FEATURES',
#     'Opinion': 'loved',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'feel',
#     'Category': 'HARDWARE#OPERATION_PERFORMANCE',
#     'Opinion': 'loved',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_136',
#   'Quadruplet': [{'Aspect': 'graphics',
#     'Category': 'GRAPHICS#GENERAL',
#     'Opinion': 'very nice',
#     'VA': '6.99#6.97'}]},
#  {'ID': 'lap26_asqp_dev_137',
#   'Quadruplet': [{'Aspect': 'computer',
#     'Category': 'LAPTOP#OPERATION_PERFORMANCE',
#     'Opinion': 'Super fast',
#     'VA': '6.99#6.97'},
#    {'Aspect': 'computer',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'awesome',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_138',
#   'Quadruplet': [{'Aspect': 'screen',
#     'Category': 'DISPLAY#DESIGN_FEATURES',
#     'Opinion': 'bright',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'screen',
#     'Category': 'DISPLAY#DESIGN_FEATURES',
#     'Opinion': 'sharp',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'screen',
#     'Category': 'DISPLAY#OPERATION_PERFORMANCE',
#     'Opinion': 'vibrant',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_139',
#   'Quadruplet': [{'Aspect': 'computer',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'loves',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_140',
#   'Quadruplet': [{'Aspect': 'Battery life',
#     'Category': 'BATTERY#OPERATION_PERFORMANCE',
#     'Opinion': 'amazing',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_141',
#   'Quadruplet': [{'Aspect': 'Battery life',
#     'Category': 'BATTERY#GENERAL',
#     'Opinion': 'very good',
#     'VA': '6.99#6.97'}]},
#  {'ID': 'lap26_asqp_dev_142',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'great',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_143',
#   'Quadruplet': [{'Aspect': 'hard drive',
#     'Category': 'HARD_DISK#OPERATION_PERFORMANCE',
#     'Opinion': 'snappy',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_144',
#   'Quadruplet': [{'Aspect': 'processor',
#     'Category': 'CPU#OPERATION_PERFORMANCE',
#     'Opinion': 'Very very slow',
#     'VA': '2.60#7.26'}]},
#  {'ID': 'lap26_asqp_dev_145',
#   'Quadruplet': [{'Aspect': 'i3 Chromebook',
#     'Category': 'LAPTOP#OPERATION_PERFORMANCE',
#     'Opinion': 'fast',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_146',
#   'Quadruplet': [{'Aspect': 'computer',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'great',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_147',
#   'Quadruplet': [{'Aspect': 'fans',
#     'Category': 'FANS_COOLING#OPERATION_PERFORMANCE',
#     'Opinion': 'not too loud',
#     'VA': '5.00#5.56'}]},
#  {'ID': 'lap26_asqp_dev_148',
#   'Quadruplet': [{'Aspect': 'battery life',
#     'Category': 'BATTERY#OPERATION_PERFORMANCE',
#     'Opinion': 'awesome',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_149',
#   'Quadruplet': [{'Aspect': 'computer',
#     'Category': 'LAPTOP#OPERATION_PERFORMANCE',
#     'Opinion': 'NULL',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_150',
#   'Quadruplet': [{'Aspect': 'mousepad',
#     'Category': 'HARDWARE#USABILITY',
#     'Opinion': 'a little off',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_151',
#   'Quadruplet': [{'Aspect': 'USB ports',
#     'Category': 'PORTS#OPERATION_PERFORMANCE',
#     'Opinion': 'great',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_152',
#   'Quadruplet': [{'Aspect': 'build quality',
#     'Category': 'LAPTOP#QUALITY',
#     'Opinion': 'Great',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'battery life',
#     'Category': 'BATTERY#GENERAL',
#     'Opinion': 'wonderful',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'screen',
#     'Category': 'DISPLAY#GENERAL',
#     'Opinion': 'NULL',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_153',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'good',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'laptop',
#     'Category': 'LAPTOP#QUALITY',
#     'Opinion': 'reasonable',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_154',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#PORTABILITY',
#     'Opinion': 'really light',
#     'VA': '5.00#5.56'}]},
#  {'ID': 'lap26_asqp_dev_155',
#   'Quadruplet': [{'Aspect': 'audio and video',
#     'Category': 'MULTIMEDIA_DEVICES#QUALITY',
#     'Opinion': 'Crisp',
#     'VA': '5.00#4.80'},
#    {'Aspect': 'video',
#     'Category': 'MULTIMEDIA_DEVICES#QUALITY',
#     'Opinion': 'Crisp',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_156',
#   'Quadruplet': [{'Aspect': 'battery life',
#     'Category': 'BATTERY#GENERAL',
#     'Opinion': 'just okay',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_157',
#   'Quadruplet': [{'Aspect': 'device',
#     'Category': 'LAPTOP#OPERATION_PERFORMANCE',
#     'Opinion': 'unbelievably bad',
#     'VA': '3.61#6.20'}]},
#  {'ID': 'lap26_asqp_dev_158',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'very impressed',
#     'VA': '5.00#5.56'}]},
#  {'ID': 'lap26_asqp_dev_159',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'pretty sweet',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_160',
#   'Quadruplet': [{'Aspect': 'Speakers',
#     'Category': 'MULTIMEDIA_DEVICES#GENERAL',
#     'Opinion': 'ok',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_161',
#   'Quadruplet': [{'Aspect': 'Shipping',
#     'Category': 'SHIPPING#OPERATION_PERFORMANCE',
#     'Opinion': 'quick',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_162',
#   'Quadruplet': [{'Aspect': 'memory',
#     'Category': 'MEMORY#GENERAL',
#     'Opinion': 'NULL',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_163',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'NULL',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_164',
#   'Quadruplet': [{'Aspect': 'battery',
#     'Category': 'BATTERY#OPERATION_PERFORMANCE',
#     'Opinion': 'good',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'battery',
#     'Category': 'BATTERY#OPERATION_PERFORMANCE',
#     'Opinion': 'really fast',
#     'VA': '6.99#6.97'}]},
#  {'ID': 'lap26_asqp_dev_165',
#   'Quadruplet': [{'Aspect': 'Keyboard',
#     'Category': 'KEYBOARD#GENERAL',
#     'Opinion': 'Nice',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'Track Pad',
#     'Category': 'KEYBOARD#GENERAL',
#     'Opinion': 'Nice',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_166',
#   'Quadruplet': [{'Aspect': 'touchscreen',
#     'Category': 'DISPLAY#OPERATION_PERFORMANCE',
#     'Opinion': 'amazingly responsive',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_167',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#PRICE',
#     'Opinion': 'Awesome',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'battery',
#     'Category': 'BATTERY#OPERATION_PERFORMANCE',
#     'Opinion': 'NULL',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_168',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'recommend',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_169',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'Excellent',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'touchscreen',
#     'Category': 'DISPLAY#OPERATION_PERFORMANCE',
#     'Opinion': 'well',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_170',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'love',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_171',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'Very happy',
#     'VA': '6.99#6.97'}]},
#  {'ID': 'lap26_asqp_dev_172',
#   'Quadruplet': [{'Aspect': 'keyboard',
#     'Category': 'KEYBOARD#DESIGN_FEATURES',
#     'Opinion': 'soft',
#     'VA': '5.00#4.80'},
#    {'Aspect': 'keyboard',
#     'Category': 'KEYBOARD#DESIGN_FEATURES',
#     'Opinion': 'comfortable',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_173',
#   'Quadruplet': [{'Aspect': 'battery life',
#     'Category': 'BATTERY#OPERATION_PERFORMANCE',
#     'Opinion': 'decent',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_174',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'love',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_175',
#   'Quadruplet': [{'Aspect': 'computer',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'NULL',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_176',
#   'Quadruplet': [{'Aspect': 'screen',
#     'Category': 'DISPLAY#OPERATION_PERFORMANCE',
#     'Opinion': 'bright',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'screen',
#     'Category': 'DISPLAY#GENERAL',
#     'Opinion': 'very good',
#     'VA': '6.99#6.97'}]},
#  {'ID': 'lap26_asqp_dev_177',
#   'Quadruplet': [{'Aspect': 'NULL',
#     'Category': 'LAPTOP#PORTABILITY',
#     'Opinion': 'not too heavy',
#     'VA': '5.00#5.56'},
#    {'Aspect': 'NULL',
#     'Category': 'LAPTOP#OPERATION_PERFORMANCE',
#     'Opinion': 'snappy',
#     'VA': '5.00#4.80'},
#    {'Aspect': 'NULL',
#     'Category': 'LAPTOP#MISCELLANEOUS',
#     'Opinion': 'cris',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_178',
#   'Quadruplet': [{'Aspect': 'processor',
#     'Category': 'CPU#OPERATION_PERFORMANCE',
#     'Opinion': 'powerful',
#     'VA': '5.00#4.80'},
#    {'Aspect': 'processor',
#     'Category': 'CPU#OPERATION_PERFORMANCE',
#     'Opinion': 'great',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_179',
#   'Quadruplet': [{'Aspect': 'display',
#     'Category': 'DISPLAY#GENERAL',
#     'Opinion': 'just okay',
#     'VA': '5.00#4.80'},
#    {'Aspect': 'display',
#     'Category': 'DISPLAY#OPERATION_PERFORMANCE',
#     'Opinion': 'not very bright',
#     'VA': '6.99#6.97'}]},
#  {'ID': 'lap26_asqp_dev_180',
#   'Quadruplet': [{'Aspect': 'Battery',
#     'Category': 'BATTERY#QUALITY',
#     'Opinion': 'trash',
#     'VA': '5.00#4.80'},
#    {'Aspect': 'Battery',
#     'Category': 'BATTERY#QUALITY',
#     'Opinion': 'NULL',
#     'VA': '5.00#4.80'},
#    {'Aspect': 'SD Hard drive',
#     'Category': 'HARD_DISK#GENERAL',
#     'Opinion': 'NULL',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_181',
#   'Quadruplet': [{'Aspect': 'Screen resolution',
#     'Category': 'DISPLAY#DESIGN_FEATURES',
#     'Opinion': 'outstandingly',
#     'VA': '5.00#4.80'},
#    {'Aspect': 'Screen resolution',
#     'Category': 'DISPLAY#DESIGN_FEATURES',
#     'Opinion': 'outstandingly',
#     'VA': '5.00#4.80'},
#    {'Aspect': 'Screen resolution',
#     'Category': 'DISPLAY#DESIGN_FEATURES',
#     'Opinion': 'outstandingly',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_182',
#   'Quadruplet': [{'Aspect': 'RAM',
#     'Category': 'MEMORY#DESIGN_FEATURES',
#     'Opinion': 'NULL',
#     'VA': '5.00#4.80'},
#    {'Aspect': 'battery',
#     'Category': 'BATTERY#DESIGN_FEATURES',
#     'Opinion': 'NULL',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_183',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'very pleased',
#     'VA': '5.00#5.56'},
#    {'Aspect': 'laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'more impressed',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_184',
#   'Quadruplet': [{'Aspect': 'battery',
#     'Category': 'BATTERY#QUALITY',
#     'Opinion': 'smaller',
#     'VA': '5.00#4.80'},
#    {'Aspect': 'battery',
#     'Category': 'BATTERY#QUALITY',
#     'Opinion': 'lighter',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_185',
#   'Quadruplet': [{'Aspect': 'computer',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'loves',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_186',
#   'Quadruplet': [{'Aspect': 'Display',
#     'Category': 'DISPLAY#OPERATION_PERFORMANCE',
#     'Opinion': 'bright',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'Display',
#     'Category': 'DISPLAY#GENERAL',
#     'Opinion': 'great',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_187',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'great',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'keyboard',
#     'Category': 'KEYBOARD#QUALITY',
#     'Opinion': 'NULL',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_188',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#MISCELLANEOUS',
#     'Opinion': 'decent',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_189',
#   'Quadruplet': [{'Aspect': 'Chromebook',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'Not happy',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_190',
#   'Quadruplet': [{'Aspect': 'keyboard',
#     'Category': 'KEYBOARD#OPERATION_PERFORMANCE',
#     'Opinion': 'not nice',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'keyboard',
#     'Category': 'KEYBOARD#OPERATION_PERFORMANCE',
#     'Opinion': 'very low',
#     'VA': '5.00#5.56'}]},
#  {'ID': 'lap26_asqp_dev_191',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#GENERAL',
#     'Opinion': 'nice',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'laptop',
#     'Category': 'LAPTOP#DESIGN_FEATURES',
#     'Opinion': 'lightweight',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_192',
#   'Quadruplet': [{'Aspect': 'computer',
#     'Category': 'LAPTOP#USABILITY',
#     'Opinion': 'easy',
#     'VA': '5.00#4.80'},
#    {'Aspect': 'computer',
#     'Category': 'LAPTOP#DESIGN_FEATURES',
#     'Opinion': 'very light',
#     'VA': '5.00#5.56'}]},
#  {'ID': 'lap26_asqp_dev_193',
#   'Quadruplet': [{'Aspect': 'keyboard',
#     'Category': 'KEYBOARD#OPERATION_PERFORMANCE',
#     'Opinion': 'NULL',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_194',
#   'Quadruplet': [{'Aspect': 'fan',
#     'Category': 'FANS_COOLING#OPERATION_PERFORMANCE',
#     'Opinion': 'a bit loud',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_195',
#   'Quadruplet': [{'Aspect': 'mouse button',
#     'Category': 'KEYBOARD#GENERAL',
#     'Opinion': "n't great",
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_196',
#   'Quadruplet': [{'Aspect': 'battery life',
#     'Category': 'BATTERY#OPERATION_PERFORMANCE',
#     'Opinion': 'Nice',
#     'VA': '6.39#6.20'},
#    {'Aspect': 'processor',
#     'Category': 'CPU#OPERATION_PERFORMANCE',
#     'Opinion': 'powerful',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_197',
#   'Quadruplet': [{'Aspect': 'computer',
#     'Category': 'LAPTOP#PRICE',
#     'Opinion': 'Great',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_198',
#   'Quadruplet': [{'Aspect': 'NULL',
#     'Category': 'LAPTOP#PRICE',
#     'Opinion': 'great',
#     'VA': '6.39#6.20'}]},
#  {'ID': 'lap26_asqp_dev_199',
#   'Quadruplet': [{'Aspect': 'ports',
#     'Category': 'PORTS#GENERAL',
#     'Opinion': 'not enough',
#     'VA': '5.00#4.80'},
#    {'Aspect': 'hard drive',
#     'Category': 'HARD_DISK#GENERAL',
#     'Opinion': 'NULL',
#     'VA': '5.00#4.80'}]},
#  {'ID': 'lap26_asqp_dev_200',
#   'Quadruplet': [{'Aspect': 'laptop',
#     'Category': 'LAPTOP#OPERATION_PERFORMANCE',
#     'Opinion': 'Great',
#     'VA': '6.39#6.20'}]}]
